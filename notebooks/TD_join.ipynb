# %%
import pandas as pd

# %%
df_dpe = pd.read_csv('../data/DPE_logements_existants_2022_final.csv', low_memory=False)
df_enedis = pd.read_csv ('../data/enedis_2022_iban_algo_dpe.csv', low_memory=False)

# %%
df_merged = pd.merge(df_dpe, df_enedis, on='Identifiant__BAN', how='inner')
print(df_merged)
# Out:
#        Date_réception_DPE N°_DPE_remplacé Etiquette_GES Etiquette_DPE  \
# 0              2022-01-03             NaN             C             D
# 1              2022-10-21             NaN             C             D
# 2              2022-03-22             NaN             B             E
# 3              2022-02-21             NaN             C             D
# 4              2022-01-03             NaN             F             G
# ...                   ...             ...           ...           ...
# 686233         2022-05-31             NaN             C             C
# 686234         2022-05-13             NaN             A             C
# 686235         2022-08-18             NaN             C             F
# 686236         2022-05-25             NaN             D             D
# 686237         2022-09-29             NaN             C             C
#
#         Année_construction Période_construction Type_bâtiment  \
# 0                   1948.0            1948-1974   appartement
# ...

# %%
df_merged.shape
# Out:
# (686238, 66)

# %%
df_merged.head()
# Out:
#   Date_réception_DPE N°_DPE_remplacé Etiquette_GES Etiquette_DPE  \
# 0         2022-01-03             NaN             C             D
# 1         2022-10-21             NaN             C             D
# 2         2022-03-22             NaN             B             E
# 3         2022-02-21             NaN             C             D
# 4         2022-01-03             NaN             F             G
#
#    Année_construction Période_construction Type_bâtiment  \
# 0              1948.0            1948-1974   appartement
# 1                 NaN            1948-1974   appartement
# 2              1948.0            1948-1974   appartement
# 3              1948.0            1948-1974   appartement
# 4              1947.0           avant 1948   appartement
#
#   Type_installation_chauffage Type_installation_ECS_(général)  \
# 0                   collectif                       collectif
# 1                   collectif                       collectif
# ...
