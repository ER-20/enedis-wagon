# %%
# import libraries
import pandas as pd
import numpy as np
import os

# chemin des dossiers de travail
DATA_PATH = '../data/raw/'
DATA_PROCESSED = '../data/processed/'
DATA_CSV = 'enedis_2022_final.csv'

DPE_TO_NUM = {'A': 35, 'B': 90, 'C': 145, 'D': 215, 'E': 290, 'F': 375, 'G': 460}
NUM_TO_DPE = {
    (0, 70): 'A',
    (70, 110): 'B',
    (110, 180): 'C',
    (180, 250): 'D',
    (250, 330): 'E',
    (330, 420): 'F',
    (420, 5000000000): 'G'
}
# import du csv
df = pd.read_csv(os.path.join(DATA_PROCESSED, DATA_CSV))

# %%
def moy_liste_de_lettres(valeur, DPE_TO_NUM=DPE_TO_NUM) -> int:
    if isinstance(valeur, str):
        # eval() -> converti en liste
        return int(np.mean([DPE_TO_NUM[lettre] for lettre in eval(valeur)])) # valeur = "[1, 2, 5]"

# %%
df["dpe_converti_conso_moyen"] = df["LIST_CLASS_DPE"].map(moy_liste_de_lettres)

# %%
def dpe_conso_to_letter(valeur, NUM_TO_DPE=NUM_TO_DPE) -> str:
    # Define the bins and labels using the NUM_TO_DPE dictionary
    bins = [num_range[0] for num_range in NUM_TO_DPE.keys()] + [float('inf')]
    labels = [dpe_score for dpe_score in NUM_TO_DPE.values()]
    # Use pd.cut() to bin the values into the appropriate DPE scores
    s_dpe = pd.cut(valeur, bins=bins, labels=labels, right=False)
    return s_dpe

# %%
df["dpe_calcule_sur_conso"] = dpe_conso_to_letter(df["dpe_converti_conso_moyen"])
df
# Out:
#      nombre_de_logements  consommation_annuelle_totale_de_l_adresse_mwh  \
# 0                     17                                         31.252
# 1                     15                                         28.374
# 2                     10                                         38.522
# 3                     17                                         89.820
# 4                     13                                         19.302
# ..                   ...                                            ...
# 212                   11                                         25.976
# 213                   13                                        106.617
# 214                   19                                         37.060
# 215                   18                                         21.213
# 216                   15                                         73.694
#
#      consommation_annuelle_moyenne_par_site_de_l_adresse_mwh  \
# 0                                                1.838
# 1                                                1.892
# 2                                                3.852
# 3                                                5.284
# 4                                                1.485
# ..                                                 ...
# 212                                              2.361
# 213                                              8.201
# 214                                              1.951
# 215                                              1.179
# 216                                              4.913
#
#      consommation_annuelle_moyenne_de_la_commune_mwh    Identifiant__BAN  \
# 0                                              4.013    48140_0328_00038
# 1                                              3.639    48061_0020_00096
# 2                                              3.639    48061_0020_00072
# 3                                              4.050    48092_b270_00009
# 4                                              4.050  48092_inwhls_00001
# ..                                               ...                 ...
# 212                                            3.586    09225_0480_00002
# 213                                            3.586    09225_3320_00049
# 214                                            3.586    09225_1390_00001
# 215                                            3.586    09225_1670_00032
# 216                                            3.586    09225_1680_00028
#
#                                LIST_CLASS_DPE  dpe_converti_conso_moyen  \
# 0                                         NaN                       NaN
# 1                                         NaN                       NaN
# 2                             ['D', 'D', 'F']                     268.0
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
# ..                                        ...                       ...
# 212                 ['D', 'C', 'D', 'D', 'D']                     201.0
# 213                      ['C', 'D', 'D', 'C']                     180.0
# 214                                     ['D']                     215.0
# 215                 ['C', 'C', 'C', 'C', 'C']                     145.0
# 216  ['G', 'E', 'D', 'G', 'D', 'C', 'G', 'F']                     327.0
#
#     dpe_calcule_sur_conso
# 0                     NaN
# 1                     NaN
# 2                       E
# 3                     NaN
# 4                     NaN
# ..                    ...
# 212                     D
# 213                     D
# 214                     D
# 215                     C
# 216                     E
#
# [217 rows x 8 columns]

# %%
df.to_csv(os.path.join(DATA_PROCESSED, 'enedis_2022_final_calculs.csv'), index=False)

# %%
"""
seq = [2, 4, 6, 8]
new = []
for el in seq:
    new.append(el**2)
new
"""
# Out:
# '\nseq = [2, 4, 6, 8]\nnew = []\nfor el in seq:\n    new.append(el**2)\nnew\n'

# %%
"""
seq = [2, 4, 6, 8]
# liste comprehensive
[el**3 for el in seq]
"""
# Out:
# '\nseq = [2, 4, 6, 8]\n# liste comprehensive\n[el**3 for el in seq]\n'
